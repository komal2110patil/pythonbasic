# %%
# 1] write a python programme to print "Hello, World"?
#ans- #include<stdio.h>
# int main(){
    #print("Hello,World")
    #return 0:
    #}

# 2] write a python programme that displays your name and age.
# ans- #age = input("Enter your name: ")
       #name = input("Enter your name: ")
       #print("Hi, my name is "+name+", and I am "+age+" years old.")

# 3] write code to print all pre-defined keywords in python using the keyword library
#ans- print("The list of keywords is : ")
#print(keyword.kwlist)

# 4] write a programme that check if a given keyword is python keyword?
#ans- import keyword
#s = input('enter any word')
#if keyword.iskeyword(s):
#    print('your enter word is keyword in python')
#else:
#    print('your enter word is not a keyword in python')

# 5] create a list and tuple in python , and demonstrate how attempting to change an elements works differently for each.
#ans- list1 = [1, 2, 3, 'ajay']
#list1[0] = "mango"
#list1
#["mango", 2, 3, 'ajay]
#tuple1 = (3, 4, 5, 'vijay')
#tuple1[0] = 'sanjay'
#tuple1
#it will throw an error

# 6] write a function to demonstrate the behavior of mutable and immutable arguments
# (1)immutable objects
#def fun():
#   a = a+2
#   print(a)
#num = 10
#fun(num)
#(2) mutable objects
#def fun(l):
#  l[0] = 99
#  print(l)
#list_new = [1, 2, 3]
#fun(list_new)
#print(new_list)

# 7] write a programme to demonstrate the use of logical oprators
# ans- a = 5
#b = 6
#print((a < 2) or (b < 6))
#print((a < 2)) and (b < 6))
#print(not(a < 2))

# 8]write a python programme to convert user input from string to integer , float and boolean types
#my_string = input("Enter  a string / Float / Integer : ")
#try:
#    value = int(my_string)
#except ValueError:
#try:
#     value = float(my_string)
#except ValueError:
#    print(Given string cannot be parsed to Float or Integer")
#else:
#    print(Given string is a float ", value)
#else:
#    print("Given string is a integer", value)

# 9] write a code to demonstrate the type casting with lists elements.
# ans- a = [ "1", "2", "3", "4", "5"]
#list(map(int, a))

# 10] write a programme that check if a number is positive, negative or zero.
#ans- num = float(input("Enter your name : "))
#if num>0:
#    print("positive number")
#elif num==0:
#     print("zero")
#else:
#     print("negative number")

# 11] write a for loops to print numbers from 1 to 10.
#for i in range(1, 10):
#    print(i, end=" ")

# 12] write a python programme to find the sum of all even numbers between 1 to 5o.
# ans- i = 2
#while i<=50:
#    print(i)
#    i = i+2

# 13] write a programme to reverse a string using a while loop
#s = input('Enter some string to reverse: ')
#output = ''
#i = len(s)-1
#while i>=0:
#     output = output + s[i]
#    i = i-1
#print(output)

# 14] write a python programme to calculate the factorial of a number provided by the user using while loop.
#factorial <3- function(n) {
#    result <- 1
#    while (n > 0) {
#        result <- result * n
#       n <- n - 1
#   }
#   return result
#}
